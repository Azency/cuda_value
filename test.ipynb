# %%
(100.0217 - 99.9958)
# Out:
# 0.02589999999999293

# %%
(5461 -5161)/762 * 221-461
# Out:
# -373.99212598425197

# %%
200/425*223-233
# Out:
# -128.05882352941177

# %%
100.0096 - 99.9401
# Out:
# 0.069500000000005

# %%
(3008 - 2705)/695*96 + 705
# Out:
# 746.853237410072
